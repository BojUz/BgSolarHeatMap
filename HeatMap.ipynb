# %%
import urllib
import urllib.request
ID = 18700
lastID = ID -1
flag =0
while(flag<500):
    response = urllib.request.urlopen('https://portal.seea.government.bg/bg/Map/GetObjectInfo/?objectId='+str(ID)+'&layer=AUER%3Abk_object')
    html = response.read()
    # print(code)
    # print(html)
    words = str(html).split('\\')
    # print(words[2])
    if(words[2]=='n<!DOCTYPE html>'):
        if(lastID+1==ID):
            concurent = True
            flag = flag+1
            # print(ID,concurent)
            print(response.getcode())
        else: 
            concurent = False
            print(ID,concurent)
            print(response.getcode())
        
        lastID = ID
    ID = ID+1
# Out:
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# ...

# %%
import cyrtranslit
import urllib
import urllib.request
import csv
def switch(code):
    if code == "Аврен":
      return "43.11492;27.66943"
    elif code == "Баните":
      return "41.61675;25.00718"
    elif code == "Бобов дол":
      return "bobovdol"
    elif code == "Бойница":
      return "43.9534912;22.5326053"
    elif code == "Болярово":
      return "42.15061;26.81198"
    elif code == "Братя Даскалови":
      return "42.30073;25.21038"
    elif code == "Венец":
      return "43.54287;26.92223"
    elif code == "Ветрино":
      return "43.31594;27.43305"
    elif code == "Вълчи дол":
      return "vulchidol"
    elif code == "Георги Дамяново":
      return "43.38477;23.0299"
    elif code == "Горна Оряховица":
      return "gorna-oryakhovitsa"
    elif code == "Димово":
      return "43.7422257;22.7349159"
    elif code == "Добрич-селска":
      return "dobrich"
    elif code == "Елхово":
      return "elkhovo"
    elif code == "Исперих":
      return "isperikh"
    elif code == "Ихтиман":
      return "ikhtiman"
    elif code == "Кайнарджа":
      return "43.99228;27.50764"
    elif code == "Кирково":
      return "41.32973;25.36527"
    elif code == "Ковачевци":
      return "42.55436;22.81815"
    elif code == "Костенец":
      return "42.307;23.85572"
    elif code == "Куклен":
      return "42.03427;24.7896"
    elif code == "Лесичово":
      return "42.35652;24.11089"
    elif code == "Маджарово":
      return "41.63383;25.85986"
    elif code == "Макреш":
      return "43.76715;22.66121"
    elif code == "Марица":
      return "42.23172;24.72969"
    elif code == "Минерални бани":
      return "41.93453;25.34879"
    elif code == "Момчилград":
      return "41.52894;25.40882"
    elif code == "Невестино":
      return "42.2537;22.8491"
    elif code == "Несебър":
      return "nesebar"
    elif code == "Никола Козлево":
      return "43.5748;27.22895"
    elif code == "Опан":
      return "42.21044;25.68396"
    elif code == "Оряхово":
      return "oryakhovo"
    elif code == "Първомай":
      return "42.1016;25.22176"
    elif code == "Родопи":
      return "42.04577;24.64755"
    elif code == "Ружинци":
      return "43.62175;22.82901"
    elif code == "Ситово":
      return "41.92647;24.61588"
    elif code == "Столична":
      return "sofia"
    elif code == "Стамболово":
      return "41.77643;25.64464"
    elif code == "Струмяни":
      return "41.63893;23.20199"
    elif code == "Сухиндол":
      return "sukhindol"
    elif code == "Сърница":
      return "41.7381133;24.0244068"
    elif code == "Трекляно":
      return "42.54483;22.60246"
    elif code == "Тунджа":
      return "42.39648;26.41103"
    elif code == "Търговище":
      return "targovishte"
    elif code == "Хаджидимово":
      return "41.51675;23.8537"
    elif code == "Хайредин":
      return "khayredin"
    elif code == "Харманли":
      return "kharmanli"
    elif code == "Хисаря":
      return "khisarya"
    elif code == "Харманли":
      return "kharmanli"
    elif code == "Хитрино":
      return "43.42494;26.91687"
    elif code == "Чавдар":
      return "42.66204;24.05193"
    elif code == "Черноочене":
      return "41.76171;25.35042"
    elif code == "Чупрене":
      return "43.51523;22.66477"
    else:
      return ""
with open('municipalities.csv', mode ='r')as file:
  csvFile = csv.reader(file)
  for lines in csvFile:
    if(lines[1]=="name"):continue
    name = str(cyrtranslit.to_latin(str(lines[1]), "bg")).replace("ă","u").replace(" ","-").lower()
    try:
      response = urllib.request.urlopen('https://www.ventusky.com/'+name)
    except: print("Error name:",name)
    html = response.read()
    check = (str(name) in str(html).lower())
    if(check==False):
      name = switch(lines[1])
      # print('https://www.ventusky.com/'+name)
      response = urllib.request.urlopen('https://www.ventusky.com/'+name)
      html = response.read()
      check = not("<title>Ventusky - Wind, Rain and Temperature Maps</title>" in str(html))
      print(html)
      if(check==False):
        print(lines[1],name,check,response.getcode())
# Out:
# b'<!doctype html>\r\n<html lang="en">\r\n<head>\r\n    <meta http-equiv="X-UA-Compatible" content="IE=edge">\r\n    <meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=no">\r\n    <link rel="dns-prefetch" href="https://cdnstatic.ventusky.com">\r\n\t<link rel="dns-prefetch" href="https://data.ventusky.com">\r\n\t<link rel="dns-prefetch" href="https://api.ventusky.com">\r\n\t<link rel="dns-prefetch" href="https://webcams.ventusky.com">\r\n\r\n    <meta http-equiv="Content-Type" content="text/html; charset=utf-8">\r\n    <!-- <meta name="apple-itunes-app" content="app-id=1280984498"> -->\r\n    <title>\xd0\x90\xd0\xb2\xd1\x80\xd0\xb5\xd0\xbd - Weather Forecast Maps | Ventusky</title>\r\n    <link rel=stylesheet href="https://cdnstatic.ventusky.com/media/style.css?1719220440">\r\n    <script>\r\n    document.addEventListener(\'gesturestart\', function (e) {\r\n    e.preventDefault();\r\n    });\r\n\r\n    </script>\r\n    <meta name="des
# ...
